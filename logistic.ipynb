# %%
import tensorflow as tf
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.datasets import load_breast_cancer
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
df=load_breast_cancer()

# %%
X_train,X_test,y_train,y_test=train_test_split(df.data,df.target,test_size=0.20,random_state=42)

# %%
sc=StandardScaler()
X_train=sc.fit_transform(X_train)
X_test=sc.transform(X_test)

# %%
model=Sequential([Dense(1,activation='sigmoid',input_shape=(X_train.shape[1],))])

# %%
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
model.fit(X_train,y_train,epochs=5)
# Out:
# Epoch 1/5
# 15/15 [==============================] - 1s 6ms/step - loss: 0.9005 - accuracy: 0.4396
# Epoch 2/5
# 15/15 [==============================] - 0s 3ms/step - loss: 0.7840 - accuracy: 0.5121
# Epoch 3/5
# 15/15 [==============================] - 0s 2ms/step - loss: 0.6873 - accuracy: 0.5912
# Epoch 4/5
# 15/15 [==============================] - 0s 4ms/step - loss: 0.6077 - accuracy: 0.6681
# Epoch 5/5
# 15/15 [==============================] - 0s 2ms/step - loss: 0.5440 - accuracy: 0.7538

# %%
y_pred=model.predict(X_test)
# Out:
# 4/4 [==============================] - 0s 3ms/step

# %%
test_loss,test_accuracy=model.evaluate(X_test,y_test)
# Out:
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4895 - accuracy: 0.8070

# %%
print("accuracy is",test_accuracy)
# Out:
# accuracy is 0.8070175647735596

# %%
import numpy as np
import tensorflow as tp
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.datasets import load_breast_cancer
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
df = load_breast_cancer()

# %%
x_train, x_test, y_train, y_test = train_test_split(df.data,df.target,test_size=0.20,random_state=42)

# %%
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# %%
model = Sequential([Dense(1,activation='sigmoid',input_shape=(x_train.shape[1],))])
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['Accuracy'])
model.fit(x_train,y_train,epochs=5)
y_pred = model.predict(x_test)
loss, accuracy = model.evaluate(x_test,y_test)
print(loss, accuracy)
# Out:
# Epoch 1/5
# 15/15 [==============================] - 2s 12ms/step - loss: 0.5787 - Accuracy: 0.6813
# Epoch 2/5
# 15/15 [==============================] - 0s 11ms/step - loss: 0.5054 - Accuracy: 0.7714
# Epoch 3/5
# 15/15 [==============================] - 0s 8ms/step - loss: 0.4460 - Accuracy: 0.8286
# Epoch 4/5
# 15/15 [==============================] - 0s 12ms/step - loss: 0.3982 - Accuracy: 0.8637
# Epoch 5/5
# 15/15 [==============================] - 0s 9ms/step - loss: 0.3596 - Accuracy: 0.8901
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3684 - Accuracy: 0.8772
# 0.36839476227760315 0.8771929740905762
