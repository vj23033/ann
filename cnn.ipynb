# %%
import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from tensorflow.keras.utils import to_categorical

(X_train, y_train), (X_test, y_test) = mnist.load_data()
X_train = X_train.reshape(-1, 28, 28, 1) / 255.0
X_test = X_test.reshape(-1, 28, 28, 1) / 255.0
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    Flatten(),
    Dense(64, activation='relu'),
    Dense(10, activation='softmax')
])

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

model.fit(X_train, y_train, batch_size=64, epochs=10, verbose=1)

loss, accuracy = model.evaluate(X_test, y_test)
print(f"Test Loss: {loss}")
print(f"Test Accuracy: {accuracy}")
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 4s 0us/step
# Epoch 1/10
# 938/938 [==============================] - 24s 25ms/step - loss: 0.1954 - accuracy: 0.9399
# Epoch 2/10
# 938/938 [==============================] - 23s 25ms/step - loss: 0.0495 - accuracy: 0.9844
# Epoch 3/10
# 938/938 [==============================] - 24s 26ms/step - loss: 0.0356 - accuracy: 0.9889
# Epoch 4/10
# 938/938 [==============================] - 23s 25ms/step - loss: 0.0279 - accuracy: 0.9910
# Epoch 5/10
# 938/938 [==============================] - 23s 24ms/step - loss: 0.0221 - accuracy: 0.9929
# Epoch 6/10
# 938/938 [==============================] - 24s 25ms/step - loss: 0.0179 - accuracy: 0.9941
# Epoch 7/10
# 938/938 [==============================] - 23s 24ms/step - loss: 0.0162 - accuracy: 0.9949
# Epoch 8/10
# 938/938 [==============================] - 19s 21ms/step - loss: 0.0116 - accuracy: 0.9964
# Epoch 9/10
# 938/938 [==============================] - 20s 21ms/step - loss: 0.0118 - accuracy: 0.9961
# Epoch 10/10
# 938/938 [==============================] - 21s 22ms/step - loss: 0.0097 - accuracy: 0.9968
# 313/313 [==============================] - 3s 8ms/step - loss: 0.0290 - accuracy: 0.9917
# Test Loss: 0.029026007279753685
# Test Accuracy: 0.9916999936103821

# %%
import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from tensorflow.keras.utils import to_categorical

# %%
(x_train, y_train), (X_test, y_test) = mnist.load_data()
x_train = x_train.reshape(-1, 28, 28, 1) / 255.0
x_test = X_test.reshape(-1, 28, 28, 1) / 255.0
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %%
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)),
    MaxPooling2D((2,2)),
    Conv2D(64,(3,3),activation='relu'),
    MaxPooling2D((2,2)),
    Conv2D(64,(3,3),activation='relu'),
    Flatten(),
    Dense(64,activation='relu'),
    Dense(10,activation='softmax')
])

model.compile(optimizer='adam',loss='categorical_crossentropy', metrics=['Accuracy'])
model.fit(x_train,y_train, batch_size=64, epochs=10, verbose=1)

loss, accuracy = model.evaluate(x_test,y_test)
print(loss, accuracy)
# Out:
# Epoch 1/10
# 938/938 [==============================] - 58s 60ms/step - loss: 0.1867 - Accuracy: 0.9429
# Epoch 2/10
# 938/938 [==============================] - 50s 53ms/step - loss: 0.0496 - Accuracy: 0.9847
# Epoch 3/10
# 938/938 [==============================] - 52s 56ms/step - loss: 0.0349 - Accuracy: 0.9893
# Epoch 4/10
# 938/938 [==============================] - 51s 54ms/step - loss: 0.0273 - Accuracy: 0.9911
# Epoch 5/10
# 938/938 [==============================] - 47s 50ms/step - loss: 0.0216 - Accuracy: 0.9931
# Epoch 6/10
# 938/938 [==============================] - 51s 55ms/step - loss: 0.0181 - Accuracy: 0.9939
# Epoch 7/10
# 938/938 [==============================] - 50s 53ms/step - loss: 0.0143 - Accuracy: 0.9954
# Epoch 8/10
# 938/938 [==============================] - 51s 54ms/step - loss: 0.0119 - Accuracy: 0.9960
# Epoch 9/10
# 938/938 [==============================] - 58s 62ms/step - loss: 0.0103 - Accuracy: 0.9967
# Epoch 10/10
# 938/938 [==============================] - 53s 57ms/step - loss: 0.0103 - Accuracy: 0.9965
# 313/313 [==============================] - 3s 9ms/step - loss: 0.0287 - Accuracy: 0.9923
# 0.028663648292422295 0.9922999739646912
